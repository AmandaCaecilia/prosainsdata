# %% [markdown]
# # Tugas 1 - Crawling data Twitter

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 4.2 MB/s eta 0:00:00
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
tweet_list = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('puan maharani since:2022-01-01 until:2023-02-22').get_items()):
  if i>500:
    break
  tweet_list.append([tweet.user.username,tweet.content,tweet.user.location])
# Out:
# <ipython-input-5-3516e76d157e>:5: FutureWarning: content is deprecated, use rawContent instead
#   tweet_list.append([tweet.user.username,tweet.content,tweet.user.location])

# %%
frame_tweet = pd.DataFrame(tweet_list,columns =['Akun','Konten','Lokasi'])
frame_tweet
# Out:
#                 Akun                                             Konten  \
# 0             qaidu3  @DedekIak @PdipSolid @puanmaharani_ri Iya la T...
# 1           dea29808  @muhammadd_deni @puanmaharani_ri KA kendaraan ...
# 2           dea29808  @RitasariiSari @puanmaharani_ri top markotop p...
# 3           dea29808  @PdipSolid @puanmaharani_ri Kl saya mah ke pal...
# 4             qaidu3  @PdipSolid @puanmaharani_ri Iya semoga tahun i...
# ..               ...                                                ...
# 496       ChaUnk_VR1  @ngahAqthar_ @lovelands_ @puanmaharani_ri Semo...
# 497          KDien24  @KejaksaanRI BRAVO @ST_Burhanuddin  Terpenuhin...
# 498       lovelands_                   @ChaUnk_VR1 @puanmaharani_ri 🤣🤣🤣
# 499  Yuliant95452148  @itsamareguzel @puanmaharani_ri bisa jd lg mod...
# 500          Mar33Cj  @arvindonoviar @PDI_Perjuangan @puanmaharani_r...
#
#                      Lokasi
# 0
# 1
# 2
# 3
# 4
# ..                      ...
# ...

# %%
frame_tweet.to_csv('tweet_puan.csv')
